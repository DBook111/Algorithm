# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 初始化数组
arr: list[int] = [0] * 5
nums: list[int] = [1, 2, 3, 4, 5]
# Out:
# 运行具有“env (Python 3.10.14)”的单元格需要ipykernel包。
#
# 运行以下命令，将 "ipykernel" 安装到 Python 环境中。
#
# 命令: "conda install -p d:\SoftWare\AcademicGPT\OneKeyInstallerForWindowsAndMacOS\installer_files\env ipykernel --update-deps --force-reinstall"
